# %%
import requests

# %%
dir(requests)
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'JSONDecodeError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet_version',
#  'charset_normalizer_version',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
# ...

# %%
requests.get?

# %%
result = requests.get('https://www.nationsonline.org/gallery/Turkey/Antalya-Mediterranean-Sea.jpg')

# %%
result
# Out:
# <Response [200]>

# %%
result.status_code
# Out:
# 200

# %%
result.content
# Out:
# b'\xff\xd8\xff\xe1\x00\x02\xff\xdb\x00\x84\x00\n\x07\x07\x07\x08\x07\n\x08\x08\n\x0e\t\x08\t\x0e\x11\r\n\n\r\x11\x14\x10\x10\x11\x10\x10\x14\x13\x0f\x11\x10\x10\x11\x0f\x13\x13\x17\x17\x19\x17\x17\x13\x1e\x1e  \x1e\x1e,+++,1111111111\x01\x0b\t\t\x0b\x0c\x0b\r\x0b\x0b\r\x11\x0e\x0e\x0e\x11\x14\x0e\x0e\x0e\x0e\x14\x18\x10\x10\x11\x10\x10\x18\x1e\x16\x13\x13\x13\x13\x16\x1e\x1b\x1d\x19\x19\x19\x1d\x1b!!\x1e\x1e!!))())1111111111\xff\xc2\x00\x11\x08\x02a\x04\xa4\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x003Q{\xfc\xb6`\x8d\x12>\x00XP"\xc0\xac\x8b\x92\xe7M-\xc1M\xc4\xf2S\t\xabs\n3\xa5\x1c\xeb\xd3\xa0\\\xfa:\x03\xcf\x93}bZ4\x94o\x82\x81B\x82\nHI!$\x84A\x12HI!$\x84\x8a\x01(\x08\xa0"F\x92F\xa7%jz\x18\x9c\x86\xa7(\t\xc8jr\x1a\x9c\x86\x
# ...

# %%
file = open("turk.jpg", "wb")

# %%
file.write(result.content)
# Out:
# 174578

# %%
file.close()

# %%
# Another way

# %%
with open("another_turk.jpg","wb") as f:
    f.write(result.content)

# %%
# in this way we dont need to close the file as the file will be closed as soon as we leave the block of
